# %% [markdown]
# ### ```Predicting Ethereum Prices in USD for the next 30 Days``` ###

# %%
import requests as req
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from api import key # api key is from cryptocompare.com

# api key, symbol, currency, and limit
API, SYM, CUR, LIM = key, "ETH", "USD", 2000

resp = req.get(f"https://min-api.cryptocompare.com/data/v2/histoday?fsym={SYM}&tsym={CUR}&limit={LIM}&api_key={API}")

# %%
# convert response to json
data = resp.json()
# convert json to dataframe
df = pd.DataFrame(data["Data"]["Data"])
# convert unix time to datetime
df["time"] = pd.to_datetime(df["time"], unit="s")
# set time as index
df.set_index("time", inplace=True)
# drop unnecessary columns
df = df[['close']]
# rename close to price
df = df.rename(columns={'close': 'price'})

# %%
df
# Out:
#               price
# time
# 2017-10-23   285.27
# 2017-10-24   296.50
# 2017-10-25   296.35
# 2017-10-26   295.54
# 2017-10-27   296.36
# ...             ...
# 2023-04-11  1891.58
# 2023-04-12  1918.78
# 2023-04-13  2013.84
# 2023-04-14  2101.61
# 2023-04-15  2090.16
#
# [2001 rows x 1 columns]

# %% [markdown]
# ##### Get Linear Regression Model

# %%
# Split data into training and testing sets
train = np.array(range(len(df))).reshape(-1, 1)
test = np.array(df['price'])
train_data_X, _, train_data_Y, _ = train_test_split(train, test, test_size=0.2, shuffle=False)

# Train linear regression model
lin_model = LinearRegression()
lin_model.fit(train_data_X, train_data_Y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Plot Historical Statistics and Predicted Values

# %%
# Plot historical prices
plt.figure(figsize=(12,6))
sns.set(style="darkgrid")
sns.lineplot(data=df, x=df.index, y="price")
plt.xlabel('Date')
plt.ylabel(f'Price ({CUR})')
plt.title(f'{SYM} Historical Prices')
plt.show()

# %%
month = 30
future_dates = pd.date_range(start=df.index[-1], periods=month + 1, freq='D')[1:]
future_X = np.array(range(len(df), len(df) + month)).reshape(-1, 1)
future_y = lin_model.predict(future_X)

# Plot predicted prices
plt.figure(figsize=(12,6))
sns.set(style="darkgrid")
sns.lineplot(x=future_dates, y=future_y)
plt.xlabel('Date')
plt.ylabel(f'Price ({CUR})')
plt.title(f'{SYM} Predicted Prices')
plt.show()

# %% [markdown]
# ### Using ANN **(Artificial Neural Network)** Model

# %%
scale = MinMaxScaler(feature_range=(0, 1))
data = scale.fit_transform(df.values)

train_size = int(len(data) * 0.8)
train_data = data[:train_size]
test_data = data[train_size:]

def create_dataset(data, look_back=1):
    X, Y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:(i + look_back), 0])
        Y.append(data[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 60
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

seq_model = Sequential()
seq_model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
seq_model.add(Dropout(0.2))
seq_model.add(LSTM(units=50, return_sequences=True))
seq_model.add(Dropout(0.2))
seq_model.add(LSTM(units=50))
seq_model.add(Dropout(0.2))
seq_model.add(Dense(units=1))
seq_model.compile(optimizer='adam', loss='mean_squared_error')

seq_model.fit(X_train, y_train, epochs=100, batch_size=32)

y_pred = seq_model.predict(X_test)
y_pred = scale.inverse_transform(y_pred)
y_test = scale.inverse_transform(y_test.reshape(-1, 1))
# Out:
# Epoch 1/100
# 49/49 [==============================] - 6s 41ms/step - loss: 0.0133
# Epoch 2/100
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0039
# Epoch 3/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.
100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0018
# Epoch 55/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0014
# Epoch 56/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0012
# Epoch 57/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0012
# Epoch 58/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0016
# Epoch 59/100
# 49/49 [==============================] - 2s 44ms/step - loss: 0.0012
# Epoch 60/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0011
# Epoch 61/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0011
# Epoch 62/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0011
# Epoch 63/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0011
# Epoch 64/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0011
# Epoch 65/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0011
# Epoch 66/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0012
# Epoch 67/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0012
# Epoch 68/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0011
# Epoch 69/100
# 49/49 [==============================] - 2s 47ms/step - loss: 0.0012
# Epoch 70/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0011
# Epoch 71/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0011
# Epoch 72/100
# 49/49 [==============================] - 3s 56ms/step - loss: 0.0012
# Epoch 73/100
# 49/49 [==============================] - 3s 51ms/step - loss: 0.0012
# Epoch 74/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0010
# Epoch 75/100
# 49/49 [==============================] - 3s 52ms/step - loss: 0.0014
# Epoch 76/100
# 49/49 [==============================] - 2s 48ms/step - loss: 9.2756e-04
# Epoch 77/100
# 49/49 [==============================] - 3s 53ms/step - loss: 0.0011
# Epoch 78/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0010
# Epoch 79/100
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0011
# Epoch 80/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0010
# Epoch 81/100
# 49/49 [==============================] - 2s 43ms/step - loss: 9.7134e-04
# Epoch 82/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0011
# Epoch 83/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0014
# Epoch 84/100
# 49/49 [==============================] - 2s 45ms/step - loss: 9.5994e-04
# Epoch 85/100
# 49/49 [==============================] - 2s 46ms/step - loss: 0.0012
# Epoch 86/100
# 49/49 [==============================] - 2s 49ms/step - loss: 0.0011
# Epoch 87/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0010
# Epoch 88/100
# 49/49 [==============================] - 2s 50ms/step - loss: 0.0012
# Epoch 89/100
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0010
# Epoch 90/100
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0010
# Epoch 91/100
# 49/49 [==============================] - 2s 45ms/step - loss: 0.0011
# Epoch 92/100
# 49/49 [==============================] - 2s 48ms/step - loss: 0.0014
# Epoch 93/100
# 49/49 [==============================] - 2s 43ms/step - loss: 0.0012
# Epoch 94/100
# 49/49 [==============================] - 2s 43ms/step - loss: 8.8522e-04
# Epoch 95/100
# 49/49 [==============================] - 3s 52ms/step - loss: 0.0011
# Epoch 96/100
# 49/49 [==============================] - 2s 48ms/step - loss: 9.0451e-04
# Epoch 97/100
# 49/49 [==============================] - 2s 49ms/step - loss: 9.7010e-04
# Epoch 98/100
# 49/49 [==============================] - 2s 51ms/step - loss: 9.8632e-04
# Epoch 99/100
# 49/49 [==============================] - 3s 51ms/step - loss: 9.5323e-04
# Epoch 100/100
# 49/49 [==============================] - 3s 53ms/step - loss: 0.0010
# 11/11 [==============================] - 1s 19ms/step

# %% [markdown]
# #### Graph using ANN

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title(f'{SYM} Price Prediction (LSTM)')
plt.xlabel('Time')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %% [markdown]
# ### ```Is this data and modelling predictions accurate? 🤷``` ###
